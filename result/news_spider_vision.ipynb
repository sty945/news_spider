# %%
import pyecharts
from pyecharts import Bar
from pyecharts import online
import json
import codecs
path = '.\\11result.json'
with open(path, 'r', encoding='utf-8') as f:
    temp = json.load(f)
    list = []
    list = temp
temp = []
for i in list:
    temp.append(i)

print(len(temp))
# for i in temp:
#     try:
#         i['nums'] = int(i['nums'])
#     except:
#         print('error')

dic_n_new = {} #新词
dic_nr = {} # 人名
dic_ns = {} # 地名
dic_nt = {} # 机构团体名
dic_nz = {} # 其它专名

res_n_new = [] #新词
res_nr = [] # 人名
res_ns = [] # 地名
res_nt = [] # 机构团体名
res_nz = [] # 其它专名
for i in temp:
    try:
        if i['cates'] == 'n_new': 
            if i['words'] in dic_n_new:
                dic_n_new[i['words']] = dic_n_new[i['words']] + i['nums']
            else:
                dic_n_new[i['words']] = i['nums']
        if i['cates'] == 'nr':
            if i['words'] in dic_nr:
                dic_nr[i['words']] = dic_nr[i['words']] + i['nums']
            else:
                dic_nr[i['words']] = i['nums']
        if i['cates'] == 'ns':
            if i['words'] in dic_ns:
                dic_ns[i['words']] = dic_ns[i['words']] + i['nums']
            else:
                dic_ns[i['words']] = i['nums']
        if i['cates'] == 'nt':
            if i['words'] in dic_nt:
                dic_nt[i['words']] = dic_nt[i['words']] + i['nums']
            else:
                dic_nt[i['words']] = i['nums']
        if i['cates'] == 'nz':
            if i['words'] in dic_nz:
                dic_nz[i['words']] = dic_nz[i['words']] + i['nums']
            else:
                dic_nz[i['words']] = i['nums']       
    except:
        pass

#处理各个词性的数据，最后逆序排列
def deal(res, dic):
    res.clear()
    c = {}
    for key in dic:
        c['words'] = key
        c['nums'] = dic[key]
        res.append(c)
        c = {}
    res.sort(key = lambda x:x['nums'])
    res.reverse() 

# 输出list数据
def output(res, num = 40):
    for i in res[:num]:
        print(i)
# Out:
# 188345

# %%
deal(res_n_new, dic_n_new) #进行数据储存
output(res_n_new, 30) #数据输出
attr_n_new = []
value_n_new = []
for n_new in res_n_new[4:30]:
    attr_n_new.append(n_new['words'])
    value_n_new.append(n_new['nums'])
bar = Bar("2017年11月份名词记", "2017年11月出现频率最高的名词")
bar.add("主视图", attr_n_new, value_n_new, xaxis_interval=0, xaxis_rotate=30, yaxis_rotate=30)
bar
# Out:
# {'words': '微信', 'nums': 832}
# {'words': '告诉记者', 'nums': 815}
# {'words': '犯罪嫌疑人', 'nums': 810}
# {'words': '公安机关', 'nums': 493}
# {'words': '双11', 'nums': 361}
# {'words': '共享单车', 'nums': 348}
# {'words': '安全隐患', 'nums': 310}
# {'words': '野生动物', 'nums': 282}
# {'words': '微博', 'nums': 268}
# {'words': '主播', 'nums': 227}
# {'words': '客服', 'nums': 226}
# {'words': '工作人员', 'nums': 205}
# {'words': '淘宝', 'nums': 189}
# {'words': '公民个人信息', 'nums': 172}
# {'words': '网购', 'nums': 167}
# {'words': '精准', 'nums': 153}
# {'words': '携程亲子园', 'nums': 153}
# {'words': '导盲犬', 'nums': 150}
# {'words': '巡察', 'nums': 147}
# {'words': '搜救', 'nums': 146}
# {'words': '王先生', 'nums': 146}
# {'words': '判处有期徒刑', 'nums': 143}
# {'words': '检察机关', 'nums': 142}
# {'words': '中国青年报', 'nums': 137}
# {'words': '刑事拘留', 'nums': 129}
# {'words': '个人信息', 'nums': 124}
# {'words': '专项行动', 'nums': 124}
# {'words': '筛查', 'nums': 119}
# {'words': '办案民警', 'nums': 114}
# {'words': '碰瓷', 'nums': 114}
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="1488b7eefba643a7ba052b664b5c9162" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('1488b7eefba643a7ba052b664b5c9162'));
# var option =  {
#     "title": [
#         {
#             "text": "2017\u5e7411\u6708\u4efd\u540d\u8bcd\u8bb0",
#             "subtext": "2017\u5e7411\u6708\u51fa\u73b0\u9891\u7387\u6700\u9ad8\u7684\u540d\u8bcd",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 778850,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e3b\u89c6\u56fe",
#             "data": [
#                 361,
#                 348,
#                 310,
#                 282,
#                 268,
#                 227,
#                 226,
#                 205,
#                 189,
#                 172,
#                 167,
#                 153,
#                 153,
#                 150,
#                 147,
#                 146,
#                 146,
#                 143,
#                 142,
#                 137,
#                 129,
#                 124,
#                 124,
#                 119,
#                 114,
#                 114
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 778850
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e3b\u89c6\u56fe"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u53cc11",
#                 "\u5171\u4eab\u5355\u8f66",
#                 "\u5b89\u5168\u9690\u60a3",
#                 "\u91ce\u751f\u52a8\u7269",
#                 "\u5fae\u535a",
#                 "\u4e3b\u64ad",
#                 "\u5ba2\u670d",
#                 "\u5de5\u4f5c\u4eba\u5458",
#                 "\u6dd8\u5b9d",
#                 "\u516c\u6c11\u4e2a\u4eba\u4fe1\u606f",
#                 "\u7f51\u8d2d",
#                 "\u7cbe\u51c6",
#                 "\u643a\u7a0b\u4eb2\u5b50\u56ed",
#                 "\u5bfc\u76f2\u72ac",
#                 "\u5de1\u5bdf",
#                 "\u641c\u6551",
#                 "\u738b\u5148\u751f",
#                 "\u5224\u5904\u6709\u671f\u5f92\u5211",
#                 "\u68c0\u5bdf\u673a\u5173",
#                 "\u4e2d\u56fd\u9752\u5e74\u62a5",
#                 "\u5211\u4e8b\u62d8\u7559",
#                 "\u4e2a\u4eba\u4fe1\u606f",
#                 "\u4e13\u9879\u884c\u52a8",
#                 "\u7b5b\u67e5",
#                 "\u529e\u6848\u6c11\u8b66",
#                 "\u78b0\u74f7"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 30,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
from pyecharts import WordCloud

deal(res_nr, dic_nr)
output(res_nr)

attr_nr = []
value_nr = []
for nr in res_nr:
    attr_nr.append(nr['words'])
    value_nr.append(nr['nums'])

wordcloud = WordCloud("2017年11月份人名记", "2017年11月出现频率最高的人名",width=900, height=620, title_pos="center")
wordcloud.add("人名", attr_nr[:40], value_nr[:40], word_size_range=[20, 120], shape='star')
wordcloud
# Out:
# {'words': '王某', 'nums': 396}
# {'words': '李某', 'nums': 350}
# {'words': '张某', 'nums': 321}
# {'words': '陈某', 'nums': 250}
# {'words': '刘鑫', 'nums': 206}
# {'words': '刘某', 'nums': 194}
# {'words': '江歌', 'nums': 189}
# {'words': '朱晓东', 'nums': 137}
# {'words': '李绪义', 'nums': 128}
# {'words': '杨欢', 'nums': 102}
# {'words': '赵勇', 'nums': 100}
# {'words': '赵某', 'nums': 91}
# {'words': '陈世峰', 'nums': 90}
# {'words': '黄淑芬', 'nums': 85}
# {'words': '徐利', 'nums': 81}
# {'words': '曹伊珂', 'nums': 70}
# {'words': '林某', 'nums': 69}
# {'words': '林智双', 'nums': 68}
# {'words': '朱某', 'nums': 67}
# {'words': '何某', 'nums': 66}
# {'words': '彭宇华', 'nums': 64}
# {'words': '张林苍', 'nums': 62}
# {'words': '老赖', 'nums': 61}
# {'words': '徐孟南', 'nums': 60}
# {'words': '杨晓飞', 'nums': 59}
# {'words': '段勇', 'nums': 58}
# {'words': '孙某', 'nums': 55}
# {'words': '吴某', 'nums': 55}
# {'words': '胡某', 'nums': 54}
# {'words': '郝如翔', 'nums': 51}
# {'words': '孟凡芹', 'nums': 51}
# {'words': '李伟', 'nums': 49}
# {'words': '韦某', 'nums': 49}
# {'words': '陈燕', 'nums': 48}
# {'words': '黄云彪', 'nums': 48}
# {'words': '阿伟', 'nums': 48}
# {'words': '张志菊', 'nums': 47}
# {'words': '杨莉', 'nums': 47}
# {'words': '黄某', 'nums': 47}
# {'words': '周义强', 'nums': 45}
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#          }
#     });
# </script>
# <div id="97ab8ca61baa4885b5385d9b09dedfc6" style="width:900px; height:620px;"></div>
#
# <script>
#     require([ 'echarts', 'wordcloud' ],function(ec){
# 	var myChart = ec.init(document.getElementById('97ab8ca61baa4885b5385d9b09dedfc6'));
# var option =  {
#     "title": [
#         {
#             "text": "2017\u5e7411\u6708\u4efd\u4eba\u540d\u8bb0",
#             "subtext": "2017\u5e7411\u6708\u51fa\u73b0\u9891\u7387\u6700\u9ad8\u7684\u4eba\u540d",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3044684,
#     "tooltip": {},
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u4eba\u540d",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 120
#             ],
#             "data": [
#                 {
#                     "name": "\u738b\u67d0",
#                     "value": 396,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,38,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u674e\u67d0",
#                     "value": 350,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,33,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f20\u67d0",
#                     "value": 321,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,67,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9648\u67d0",
#                     "value": 250,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,95,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5218\u946b",
#                     "value": 206,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,48,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5218\u67d0",
#                     "value": 194,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,39,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u6b4c",
#                     "value": 189,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,109,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6731\u6653\u4e1c",
#                     "value": 137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,24,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u674e\u7eea\u4e49",
#                     "value": 128,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,40,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6768\u6b22",
#                     "value": 102,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,115,55)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d75\u52c7",
#                     "value": 100,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,88,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d75\u67d0",
#                     "value": 91,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,73,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9648\u4e16\u5cf0",
#                     "value": 90,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,110,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u6dd1\u82ac",
#                     "value": 85,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,62,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f90\u5229",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,147,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u66f9\u4f0a\u73c2",
#                     "value": 70,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,32,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6797\u67d0",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,11,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6797\u667a\u53cc",
#                     "value": 68,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,148,144)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6731\u67d0",
#                     "value": 67,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,44,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f55\u67d0",
#                     "value": 66,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,135,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f6d\u5b87\u534e",
#                     "value": 64,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,22,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f20\u6797\u82cd",
#                     "value": 62,
#                     "textStyle": {
#                         "normal": {

# %%
from pyecharts import Geo
deal(res_ns, dic_ns)
# output(res_ns)
data = []
data.clear()
for ns in res_ns:
    tupl = (ns["words"], ns["nums"])
    data.append(tupl)
   
geo = Geo("全国主要城市11月份出现频率", "data from chinanews", title_color="#fff", title_pos="center",
width=800, height=600, background_color='#434a59')
attr, value = geo.cast(data)

geo.add("", attr, value, visual_range=[0, 3000], visual_text_color="#fff",
        symbol_size=15, is_visualmap=True)
geo
# Out:
# 中国 coordinates is not found
# 广东 coordinates is not found
# 浙江 coordinates is not found
# 广西 coordinates is not found
# 新疆 coordinates is not found
# 西藏 coordinates is not found
# 云南 coordinates is not found
# 河北 coordinates is not found
# 长城 coordinates is not found
# 四川 coordinates is not found
# 湖南 coordinates is not found
# 山东 coordinates is not found
# 京东 coordinates is not found
# 贵州 coordinates is not found
# 长江 coordinates is not found
# 海南 coordinates is not found
# 河南 coordinates is not found
# 九寨沟 coordinates is not found
# 安徽 coordinates is not found
# 湖南省 coordinates is not found
# 福建 coordinates is not found
# 永定河 coordinates is not found
# 甘肃 coordinates is not found
# 城隍庙 coordinates is not found
# 海南省 coordinates is not found
# 陆丰 coordinates is not found
# 共青城 coordinates is not found
# 鲁山 coordinates is not found
# 黄海 coordinates is not found
# 缅甸 coordinates is not found
# 河北省 coordinates is not found
# 都安 coordinates is not found
# 山东省 coordinates is not found
# 河南省 coordinates is not found
# 洱海 coordinates is not found
# 广东省 coordinates is not found
# 辽宁 coordinates is not found
# 乌镇 coordinates is not found
# 江苏 coordinates is not found
# 泰顺 coordinates is not found
# 台湾 coordinates is not found
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts/china'
#          }
#     });
# </script>
# <div id="6f7edaf7c2564d9e82c8f2b0935bacfc" style="width:800px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'china' ],function(ec){
# 	var myChart = ec.init(document.getElementById('6f7edaf7c2564d9e82c8f2b0935bacfc'));
# var option =  {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e0211\u6708\u4efd\u51fa\u73b0\u9891\u7387",
#             "subtext": "data from chinanews",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6482163,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 15,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.46,
#                         39.92,
#                         2255
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.48,
#                         31.22,
#                         876
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         745
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         607
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.54,
#                         29.59,
#                         280
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         230
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         197
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         191
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         188
#                     ]
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": [
#                         117,
#                         36.65,
#                         183
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         172
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         167
#                     ]
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": [
#                         123.38,
#                         41.8,
#                         126
#                     ]
#                 },
#                 {
#                     "name": "\u6843\u6c5f\u53bf",
#                     "value": [
#                         112.12,
#                         28.53,
#                         111
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": [
#                         117.27,
#                         31.86,
#                         76
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         121.47,
#                         31.23,
#                         69
#                     ]
#                 },
#                 {
#                     "name": "\u4e3d\u6c34",
#                     "value": [
#                         119.92,
#                         28.45,
#                         68
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": [
#                         110.35,
#                         20.02,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": [
#                         115.12,
#                         21.23,
#                         50
#                     ]
#                 },
#                 {
#                     "name": "\u6606\u660e",
#                     "value": [
#                         102.73,
#                         25.04,
#                         50
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.2,
#                         39.13,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         43
#                     ]
#                 },
#                 {
#                     "name": "\u9ec4\u77f3",
#                     "value": [
#                         115.06,
#                         30.12,
#                         37
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         32
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u4e9a",
#                     "value": [
#                         109.511909,
#                         18.252847,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         30
#                     ]
#                 },
#                 {
#                     "name": "\u67f3\u5dde",
#                     "value": [

# %%
from pyecharts import Map

attr_ns = []
value_ns = []
for ns in res_ns:
    attr_ns.append(ns['words'])
    value_ns.append(ns['nums'])
map = Map("11月份各省市新闻出现频率", width=800, height=600)
map.add("", attr_ns, value_ns, maptype='china', is_visualmap=True, visual_text_color='#000', is_label_show=True)
map
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts/china'
#          }
#     });
# </script>
# <div id="e8449b7cee8147c7b5274967921da086" style="width:800px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'china' ],function(ec){
# 	var myChart = ec.init(document.getElementById('e8449b7cee8147c7b5274967921da086'));
# var option =  {
#     "title": [
#         {
#             "text": "11\u6708\u4efd\u5404\u7701\u5e02\u65b0\u95fb\u51fa\u73b0\u9891\u7387",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1194817,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 3360
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2255
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 876
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 745
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 607
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 320
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 280
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 230
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 209
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": 197
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 196
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 191
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": 183
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 172
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": 167
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 152
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 123
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u957f\u57ce",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u6843\u6c5f\u53bf",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u4eac\u4e1c",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u4e3d\u6c34",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u957f\u6c5f",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 59
#                 },
#                 {
#                     "name": "\u4e5d\u5be8\u6c9f",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u6606\u660e",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u6c38\u5b9a\u6cb3",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ec4\u77f3",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u57ce\u968d\u5e99",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u6d77\u5357\u7701",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u9646\u4e30",

# %%
from pyecharts import Pie
deal(res_nt, dic_nt)
output(res_nt)
attr_nt = []
value_nt = []
for nt in res_nt:
    attr_nt.append(nt['words'])
    value_nt.append(nt['nums'])
pie = Pie("11月份出现的高频机构", title_pos='right')
pie.add("", attr_nt[2:15], value_nt[2:15], radius=[40, 75], label_text_color=None, is_label_show=True,
        legend_orient='vertical', legend_pos='left')
pie
# Out:
# {'words': '中新网', 'nums': 1142}
# {'words': '新华社', 'nums': 228}
# {'words': '公安部', 'nums': 212}
# {'words': '人民检察院', 'nums': 87}
# {'words': '国务院', 'nums': 62}
# {'words': '清华大学', 'nums': 61}
# {'words': '教育部', 'nums': 52}
# {'words': '最高人民法院', 'nums': 30}
# {'words': '中央气象台', 'nums': 28}
# {'words': '北京大学', 'nums': 25}
# {'words': '联合国', 'nums': 23}
# {'words': '气象局', 'nums': 15}
# {'words': '中央纪委', 'nums': 13}
# {'words': '新华网', 'nums': 10}
# {'words': '党中央', 'nums': 9}
# {'words': '中国共产党', 'nums': 9}
# {'words': '中央电视台', 'nums': 8}
# {'words': '新冶钢', 'nums': 7}
# {'words': '林业局', 'nums': 7}
# {'words': '中国红十字会', 'nums': 6}
# {'words': '财政局', 'nums': 6}
# {'words': '中国证监会', 'nums': 6}
# {'words': '中国人民银行', 'nums': 6}
# {'words': '中国移动', 'nums': 5}
# {'words': '农业部', 'nums': 5}
# {'words': '司法部', 'nums': 4}
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="090c093b62134110a7624d9ff903d340" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('090c093b62134110a7624d9ff903d340'));
# var option =  {
#     "title": [
#         {
#             "text": "11\u6708\u4efd\u51fa\u73b0\u7684\u9ad8\u9891\u673a\u6784",
#             "subtext": "",
#             "left": "right",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3774617,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "",
#             "data": [
#                 {
#                     "name": "\u516c\u5b89\u90e8",
#                     "value": 212
#                 },
#                 {
#                     "name": "\u4eba\u6c11\u68c0\u5bdf\u9662",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u56fd\u52a1\u9662",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u6e05\u534e\u5927\u5b66",
#                     "value": 61
#                 },
#                 {
#                     "name": "\u6559\u80b2\u90e8",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6700\u9ad8\u4eba\u6c11\u6cd5\u9662",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u4e2d\u592e\u6c14\u8c61\u53f0",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5927\u5b66",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u8054\u5408\u56fd",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u6c14\u8c61\u5c40",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u4e2d\u592e\u7eaa\u59d4",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u65b0\u534e\u7f51",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u515a\u4e2d\u592e",
#                     "value": 9
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": null,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "color": null,
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3774617
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u5b89\u90e8",
#                 "\u4eba\u6c11\u68c0\u5bdf\u9662",
#                 "\u56fd\u52a1\u9662",
#                 "\u6e05\u534e\u5927\u5b66",
#                 "\u6559\u80b2\u90e8",
#                 "\u6700\u9ad8\u4eba\u6c11\u6cd5\u9662",
#                 "\u4e2d\u592e\u6c14\u8c61\u53f0",
#                 "\u5317\u4eac\u5927\u5b66",
#                 "\u8054\u5408\u56fd",
#                 "\u6c14\u8c61\u5c40",
#                 "\u4e2d\u592e\u7eaa\u59d4",
#                 "\u65b0\u534e\u7f51",
#                 "\u515a\u4e2d\u592e"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
from pyecharts import Pie
deal(res_nz, dic_nz)
output(res_nz)

attr_nz = []
value_nz = []
for nz in res_nz:
    attr_nz.append(nz['words'])
    value_nz.append(nz['nums'])

pie = Pie("11月份高频专有名词", title_pos='center', width=900)
pie.add("商品", attr_nz[2:20], value_nz[2:20], is_random=True, radius=[30, 75], rosetype='area',
        is_legend_show=False, is_label_show=True)
pie
# Out:
# {'words': '英语', 'nums': 249}
# {'words': '中华', 'nums': 139}
# {'words': '佛教', 'nums': 71}
# {'words': '汉族', 'nums': 62}
# {'words': '扬子', 'nums': 61}
# {'words': '麦当劳', 'nums': 56}
# {'words': '新民', 'nums': 55}
# {'words': '道教', 'nums': 54}
# {'words': '雪豹', 'nums': 53}
# {'words': '熊猫', 'nums': 51}
# {'words': '阿里巴巴', 'nums': 50}
# {'words': '腾讯', 'nums': 50}
# {'words': '八大', 'nums': 42}
# {'words': '通用', 'nums': 40}
# {'words': '新华', 'nums': 38}
# {'words': '苗族', 'nums': 37}
# {'words': '英文', 'nums': 35}
# {'words': '侗族', 'nums': 34}
# {'words': '彝', 'nums': 34}
# {'words': '羌族', 'nums': 33}
# {'words': '中文', 'nums': 33}
# {'words': '东东', 'nums': 33}
# {'words': '红嘴', 'nums': 31}
# {'words': '华文', 'nums': 31}
# {'words': '藏族', 'nums': 31}
# {'words': '清华', 'nums': 30}
# {'words': '吉尼斯', 'nums': 30}
# {'words': '汉语', 'nums': 28}
# {'words': '家乐福', 'nums': 27}
# {'words': '华为', 'nums': 27}
# {'words': '海尔', 'nums': 26}
# {'words': '复旦', 'nums': 25}
# {'words': '波音', 'nums': 24}
# {'words': '奥迪', 'nums': 24}
# {'words': '百度', 'nums': 23}
# {'words': '康师傅', 'nums': 22}
# {'words': '阳光', 'nums': 21}
# {'words': '宝马', 'nums': 21}
# {'words': '南京大屠杀', 'nums': 21}
# {'words': '奔驰', 'nums': 21}
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="ba49fcb79306447e965106014d643f66" style="width:900px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('ba49fcb79306447e965106014d643f66'));
# var option =  {
#     "title": [
#         {
#             "text": "11\u6708\u4efd\u9ad8\u9891\u4e13\u6709\u540d\u8bcd",
#             "subtext": "",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7387284,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u4f5b\u6559",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u6c49\u65cf",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u626c\u5b50",
#                     "value": 61
#                 },
#                 {
#                     "name": "\u9ea6\u5f53\u52b3",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u65b0\u6c11",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u9053\u6559",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u96ea\u8c79",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u963f\u91cc\u5df4\u5df4",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u817e\u8baf",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u516b\u5927",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u901a\u7528",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u65b0\u534e",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u82d7\u65cf",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u82f1\u6587",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u4f97\u65cf",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u5f5d",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u7f8c\u65cf",
#                     "value": 33
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 7387284
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f5b\u6559",
#                 "\u6c49\u65cf",
#                 "\u626c\u5b50",
#                 "\u9ea6\u5f53\u52b3",
#                 "\u65b0\u6c11",
#                 "\u9053\u6559",
#                 "\u96ea\u8c79",
#                 "\u718a\u732b",
#                 "\u963f\u91cc\u5df4\u5df4",
#                 "\u817e\u8baf",
#                 "\u516b\u5927",
#                 "\u901a\u7528",
#                 "\u65b0\u534e",
#                 "\u82d7\u65cf",
#                 "\u82f1\u6587",
#                 "\u4f97\u65cf",
#                 "\u5f5d",
#                 "\u7f8c\u65cf"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#6d8346",
#         "#c23531",
#         "#bda29a",
#         "#f05b72",
#         "#f47920",
#         "#444693",
#         "#2a5caa",
#         "#918597",
#         "#2f4554",
#         "#1d953f",
#         "#b2d235",
#         "#fab27b",
#         "#6950a1",
#         "#749f83",
#         "#6e7074",
#         "#546570",
#         "#61a0a8",
#         "#ac6767",
#         "#c4ccd3",
#         "#726930",
#         "#f6f5ec",
#         "#ca8622",
#         "#d48265",
#         "#905a3d",
#         "#ef5b9c"
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
from pyecharts import Funnel
deal(res_nz, dic_nz)
output(res_nz)

attr_nz = []
value_nz = []
for nz in res_nz:
    attr_nz.append(nz['words'])
    value_nz.append(nz['nums'])

funnel = Funnel("一月份高频专有名词",  width=600, height=400, title_pos='right')
funnel.add("商品", attr_nz[2:15], value_nz[2:15], legend_orient='vertical', legend_pos='left',
           is_label_show=True, label_pos="inside", label_text_color="#fff")
funnel
# Out:
# {'words': '英语', 'nums': 249}
# {'words': '中华', 'nums': 139}
# {'words': '佛教', 'nums': 71}
# {'words': '汉族', 'nums': 62}
# {'words': '扬子', 'nums': 61}
# {'words': '麦当劳', 'nums': 56}
# {'words': '新民', 'nums': 55}
# {'words': '道教', 'nums': 54}
# {'words': '雪豹', 'nums': 53}
# {'words': '熊猫', 'nums': 51}
# {'words': '阿里巴巴', 'nums': 50}
# {'words': '腾讯', 'nums': 50}
# {'words': '八大', 'nums': 42}
# {'words': '通用', 'nums': 40}
# {'words': '新华', 'nums': 38}
# {'words': '苗族', 'nums': 37}
# {'words': '英文', 'nums': 35}
# {'words': '侗族', 'nums': 34}
# {'words': '彝', 'nums': 34}
# {'words': '羌族', 'nums': 33}
# {'words': '中文', 'nums': 33}
# {'words': '东东', 'nums': 33}
# {'words': '红嘴', 'nums': 31}
# {'words': '华文', 'nums': 31}
# {'words': '藏族', 'nums': 31}
# {'words': '清华', 'nums': 30}
# {'words': '吉尼斯', 'nums': 30}
# {'words': '汉语', 'nums': 28}
# {'words': '家乐福', 'nums': 27}
# {'words': '华为', 'nums': 27}
# {'words': '海尔', 'nums': 26}
# {'words': '复旦', 'nums': 25}
# {'words': '波音', 'nums': 24}
# {'words': '奥迪', 'nums': 24}
# {'words': '百度', 'nums': 23}
# {'words': '康师傅', 'nums': 22}
# {'words': '阳光', 'nums': 21}
# {'words': '宝马', 'nums': 21}
# {'words': '南京大屠杀', 'nums': 21}
# {'words': '奔驰', 'nums': 21}
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="c505dd244c9440bfa8a166d1476cd318" style="width:600px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('c505dd244c9440bfa8a166d1476cd318'));
# var option =  {
#     "title": [
#         {
#             "text": "\u4e00\u6708\u4efd\u9ad8\u9891\u4e13\u6709\u540d\u8bcd",
#             "subtext": "",
#             "left": "right",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6183396,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u4f5b\u6559",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u6c49\u65cf",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u626c\u5b50",
#                     "value": 61
#                 },
#                 {
#                     "name": "\u9ea6\u5f53\u52b3",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u65b0\u6c11",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u9053\u6559",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u96ea\u8c79",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u963f\u91cc\u5df4\u5df4",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u817e\u8baf",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u516b\u5927",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u901a\u7528",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u65b0\u534e",
#                     "value": 38
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u8c79",
#                 "\u516b\u5927",
#                 "\u6c49\u65cf",
#                 "\u4f5b\u6559",
#                 "\u65b0\u6c11",
#                 "\u9ea6\u5f53\u52b3",
#                 "\u901a\u7528",
#                 "\u626c\u5b50",
#                 "\u9053\u6559",
#                 "\u817e\u8baf",
#                 "\u65b0\u534e",
#                 "\u718a\u732b",
#                 "\u963f\u91cc\u5df4\u5df4"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>
